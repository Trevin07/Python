# %%
import pandas as pd

# %%
df=pd.read_csv('organizations-100000.csv')

# %%
df
# Out:
#         Index  Organization Id                      Name  \
# 0           1  8cC6B5992C0309c               Acevedo LLC
# 1           2  ec094061FeaF7Bc            Walls-Mcdonald
# 2           3  DAcC5dbc58946A7               Gregory PLC
# 3           4  8Dd7beDa37FbeD0  Byrd, Patterson and Knox
# 4           5  a3b5c54AEC163e4          Mcdowell-Hopkins
# ...       ...              ...                       ...
# 99995   99996  3E5e8e6a60CF9FF                Frey Group
# 99996   99997  BdfAa2aE00DaE79                Lloyd-Dyer
# 99997   99998  5c3a2EBDeC9B25b           Levine and Sons
# 99998   99999  c58E390b3dd61a5              Martinez PLC
# 99999  100000  14ab658Ad57Fcfd               Esparza Inc
#
#                             Website                        Country  \
# 0          https://www.donovan.com/  Holy See (Vatican City State)
# 1          http://arias-willis.net/                      Lithuania
# 2      http://www.lynch-hoover.net/                        Tokelau
# ...

# %%
df.loc[(df['Founded'] > 2002) & (df['Number of employees'] >= 5000)]
# Out:
#         Index  Organization Id                         Name  \
# 0           1  8cC6B5992C0309c                  Acevedo LLC
# 1           2  ec094061FeaF7Bc               Walls-Mcdonald
# 2           3  DAcC5dbc58946A7                  Gregory PLC
# 9          10  C08fcf292AB17DF  Barker, Hubbard and Bennett
# 11         12  FE42dEd40f5DfD8     Lester, Ochoa and Franco
# ...       ...              ...                          ...
# 99993   99994  b8404F23668F4Fa              Frederick-Brock
# 99996   99997  BdfAa2aE00DaE79                   Lloyd-Dyer
# 99997   99998  5c3a2EBDeC9B25b              Levine and Sons
# 99998   99999  c58E390b3dd61a5                 Martinez PLC
# 99999  100000  14ab658Ad57Fcfd                  Esparza Inc
#
#                             Website                           Country  \
# 0          https://www.donovan.com/     Holy See (Vatican City State)
# 1          http://arias-willis.net/                         Lithuania
# ...

# %%
df.groupby('Name')['Number of employees'].max()
# Out:
# Name
# Abbott Group       4698
# Abbott Inc         6559
# Abbott LLC         6869
# Abbott PLC         8263
# Abbott and Sons    8897
#                    ...
# Zuniga-Ritter      5423
# Zuniga-Rodgers     1663
# Zuniga-Stanton      198
# Zuniga-Stewart     9587
# Zuniga-Suarez      4364
# Name: Number of employees, Length: 72415, dtype: int64

# %%
df.groupby(['Industry'])['Number of employees'].agg([len, min, max])
# Out:
#                                 len  min   max
# Industry
# Accounting                      685   17  9996
# Airlines / Aviation             668   37  9998
# Alternative Dispute Resolution  705   17  9991
# Alternative Medicine            680   45  9972
# Animation                       706    2  9965
# ...                             ...  ...   ...
# Warehousing                     673   17  9994
# Wholesale                       670    4  9999
# Wine / Spirits                  652    9  9992
# Wireless                        653   13  9998
# Writing / Editing               626    1  9998
#
# [147 rows x 3 columns]

# %%
min_value = df['Number of employees'].min()
print(min_value)
# Out:
# 1

# %%
df
# Out:
#         Index  Organization Id                      Name  \
# 0           1  8cC6B5992C0309c               Acevedo LLC
# 1           2  ec094061FeaF7Bc            Walls-Mcdonald
# 2           3  DAcC5dbc58946A7               Gregory PLC
# 3           4  8Dd7beDa37FbeD0  Byrd, Patterson and Knox
# 4           5  a3b5c54AEC163e4          Mcdowell-Hopkins
# ...       ...              ...                       ...
# 99995   99996  3E5e8e6a60CF9FF                Frey Group
# 99996   99997  BdfAa2aE00DaE79                Lloyd-Dyer
# 99997   99998  5c3a2EBDeC9B25b           Levine and Sons
# 99998   99999  c58E390b3dd61a5              Martinez PLC
# 99999  100000  14ab658Ad57Fcfd               Esparza Inc
#
#                             Website                        Country  \
# 0          https://www.donovan.com/  Holy See (Vatican City State)
# 1          http://arias-willis.net/                      Lithuania
# 2      http://www.lynch-hoover.net/                        Tokelau
# ...

# %%
df.drop(columns=['Organization Id','Index'],inplace=True)
df
# Out:
#                            Name                       Website  \
# 0                   Acevedo LLC      https://www.donovan.com/
# 1                Walls-Mcdonald      http://arias-willis.net/
# 2                   Gregory PLC  http://www.lynch-hoover.net/
# 3      Byrd, Patterson and Knox  https://www.james-velez.net/
# 4              Mcdowell-Hopkins           http://fuentes.com/
# ...                         ...                           ...
# 99995                Frey Group             http://haney.com/
# 99996                Lloyd-Dyer           https://farmer.org/
# 99997           Levine and Sons       http://www.andrade.org/
# 99998              Martinez PLC        https://www.glass.biz/
# 99999               Esparza Inc          https://thomas.info/
#
#                              Country  \
# 0      Holy See (Vatican City State)
# 1                          Lithuania
# 2                            Tokelau
# 3                        Netherlands
# ...

# %%
df.sort_values('Number of employees')
# Out:
#                              Name                          Website  \
# 59573                 Riggs-Kline  http://www.bradford-mclean.org/
# 50914  Byrd, Avery and Strickland        http://monroe-bryant.com/
# 62594            Bryant-Velazquez             http://www.vega.com/
# 63779                Olson-George       https://dorsey-osborn.com/
# 61167                  Weber-Holt   http://daniels-washington.com/
# ...                           ...                              ...
# 53894                  Baker-Odom                http://nolan.com/
# 12031                 Graham-West              https://peters.com/
# 35596           Petersen and Sons           http://www.hinton.com/
# 8208               Nelson-Harrell               http://thomas.com/
# 98994             Vargas and Sons               http://stuart.com/
#
#                             Country  \
# 59573                        Mexico
# 50914                    Bangladesh
# 62594                         Macao
# ...

# %%
df['Number of employees'].describe()
# Out:
# count    100000.000000
# mean       5003.959280
# std        2889.465063
# min           1.000000
# 25%        2508.000000
# 50%        4998.000000
# 75%        7503.000000
# max        9999.000000
# Name: Number of employees, dtype: float64
